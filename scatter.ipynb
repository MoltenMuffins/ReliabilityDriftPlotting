# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.colors

from matplotlib.gridspec import GridSpec

# %%
filename = r'\\fstpdata\Team\Quality\Reliability\Public\Q-TMP-MPI-001_Datalogs\RTO-4124 - Copy\HTOL\RTO-4124_HTOL_FFT_Database.csv'
thang = pd.read_csv(filename)
thang.head()
# Out:
#    Hours         LOT_ID  PART_INDEX  PART_X  PART_Y  PART_BIN  SITE  \
# 0      0  RTO_4124_HTOL         1.0      -1       0         1     1
# 1      0  RTO_4124_HTOL         2.0       0       0         1     1
# 2      0  RTO_4124_HTOL         3.0       1       0         1     1
# 3      0  RTO_4124_HTOL         4.0       2       0         1     1
# 4      0  RTO_4124_HTOL         5.0       3       0         1     1
#
#    TOUCHDOWN_INDEX            TIMESTAMP  1_ffp_V        ...          \
# 0              NaN  2019-01-23 04:24:43    1.946        ...
# 1              NaN  2019-01-23 04:24:49    1.950        ...
# 2              NaN  2019-01-23 04:24:56    1.943        ...
# 3              NaN  2019-01-23 04:25:03    1.943        ...
# 4              NaN  2019-01-23 04:25:10    1.942        ...
#
#    3_Angle_0_deg  4_Angle_90_deg  5_Angle_45_deg  6_Angle_135_deg  7_DIP  \
# 0         24.030          24.087          23.134           23.154  67.45
# ...

# %%
labels = thang.columns
label = labels[9]
fig = plt.figure(figsize=(7,9))
cmap = plt.cm.rainbow
norm = matplotlib.colors.Normalize(vmin=1, vmax=30)
thang.plot(kind='scatter',x='Hours',y=label, c=cmap(norm(thang['PART_INDEX'].values)), figsize=(6,8), linewidths=0.5,edgecolors = 'dimgrey')
plt.grid(alpha=0.2)
plt.title('{} value vs Hours colored by Unit SN'.format(label))

sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
# fig.colorbar(sm)

clb = plt.colorbar(sm)
clb.ax.set_title('Unit')
clb.set_ticks([x for x in range(1,31)])
clb.ax.grid(alpha=0.3)

# gs = GridSpec(6,8)
ax_marg_y = fig.add_subplot(gs[1:4,3])
ax_marg_y.hist(x=thang[label],orientation="horizontal")



plt.show()

# %%
thang['Hours'].apply(lambda x: colors[x])
x_vals = [x for x in range(1,31)]

# %%
thang.plot(kind='scatter', x='PART_INDEX', c='Hours', y='1_ffp_V',figsize=(10, 8))
plt.title('Scatter Plot of Parameter vs SN')
plt.xticks(x_vals)
plt.show()

# %%
labels = thang.columns
label = labels[12]

cmap = plt.cm.rainbow
norm = matplotlib.colors.Normalize(vmin=0, vmax=1000)

fig, ax = plt.subplots(figsize=(18,8))
ax.scatter(thang['PART_INDEX'],thang[label], linewidths=0.5, edgecolors = 'dimgrey', color=cmap(norm(thang['Hours'].values)))
# ax.set_xticks(thang['PART_INDEX'])
# ax.set_facecolor('dimgrey')
plt.grid(alpha=0.1)
plt.xlabel('Unit SN')
plt.ylabel(label)


sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
# fig.colorbar(sm)

clb = plt.colorbar(sm)
clb.ax.set_title('Hrs')


plt.show()
